# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mode
from collections import Counter

DATA_PATH = "/Users/Derrick/Desktop/" # Make this the /path/to/the/data

# %%
data = pd.read_csv(open('311_Service_Requests_2015.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-db0ce558f1b4> in <module>()
# ----> 1 data = pd.read_csv(open('311_Service_Requests_2015.csv'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '311_Service_Requests_2015.csv'

# %%
data.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    30264625  03/26/2015 06:50:06 PM  07/22/2015 12:00:00 AM   DSNY
# 1    30279915  03/28/2015 04:30:52 PM  08/08/2016 12:00:00 AM    DOB
# 2    30314570  04/01/2015 04:48:00 PM  08/12/2016 04:07:00 PM    DOT
# 3    30542111  05/04/2015 04:46:00 PM  09/29/2016 06:54:00 PM    DOT
# 4    30422344  04/17/2015 01:50:07 PM                     NaN   DSNY
#
#                     Agency Name          Complaint Type  \
# 0      Department of Sanitation                Graffiti
# 1       Department of Buildings            Building/Use
# 2  Department of Transportation  Street Light Condition
# 3  Department of Transportation  Street Light Condition
# 4      Department of Sanitation                Graffiti
#
#                                         Descriptor Location Type Incident Zip  \
# 0                                         Graffiti     Mixed Use        11104
# ...

# %%
data
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 0          30264625  03/26/2015 06:50:06 PM  07/22/2015 12:00:00 AM   DSNY
# 1          30279915  03/28/2015 04:30:52 PM  08/08/2016 12:00:00 AM    DOB
# 2          30314570  04/01/2015 04:48:00 PM  08/12/2016 04:07:00 PM    DOT
# 3          30542111  05/04/2015 04:46:00 PM  09/29/2016 06:54:00 PM    DOT
# 4          30422344  04/17/2015 01:50:07 PM                     NaN   DSNY
# 5          30543106  05/04/2015 04:41:00 PM  09/29/2016 06:53:00 PM    DOT
# 6          30542875  05/04/2015 02:49:25 PM                     NaN   DSNY
# 7          30554653  05/06/2015 12:39:31 AM  08/13/2015 12:00:00 AM   DSNY
# 8          30554646  05/05/2015 10:49:36 AM  08/22/2016 12:00:00 AM    DOB
# 9          30556593  05/06/2015 01:04:44 PM  08/07/2015 12:00:00 AM   DSNY
# 10         30583844  05/09/2015 10:49:42 AM  08/08/2016 12:00:00 AM    DOB
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
(data['Created Date'])
# Out:
# 0          03/26/2015 06:50:06 PM
# 1          03/28/2015 04:30:52 PM
# 2          04/01/2015 04:48:00 PM
# 3          05/04/2015 04:46:00 PM
# 4          04/17/2015 01:50:07 PM
# 5          05/04/2015 04:41:00 PM
# 6          05/04/2015 02:49:25 PM
# 7          05/06/2015 12:39:31 AM
# 8          05/05/2015 10:49:36 AM
# 9          05/06/2015 01:04:44 PM
# 10         05/09/2015 10:49:42 AM
# 11         05/12/2015 07:09:38 AM
# 12         05/12/2015 10:54:03 AM
# 13         05/12/2015 09:42:43 PM
# 14         05/13/2015 02:52:23 PM
# 15         05/15/2015 12:51:36 PM
# 16         05/15/2015 09:58:40 PM
# 17         05/17/2015 09:42:52 AM
# 18         05/18/2015 08:49:28 AM
# 19         05/20/2015 07:18:56 AM
# 20         06/04/2015 07:22:00 PM
# 21         05/29/2015 01:22:49 PM
# 22         06/20/2015 01:18:11 PM
# 23         06/02/2015 02:30:17 PM
# 24         06/03/2015 09:20:12 PM
# 25         06/03/2015 09:12:24 PM
# 26         06/04/2015 03:14:28 AM
# ...

# %%
#Created_Date = data['Created Date']
data['Created_Date'] = data['Created Date'].str.split('.')

# %%
created_date = data['Created Date']
created_date.apply(lambda x: pd.Timestamp(x).time).value_counts()
# Out:
# <built-in method time of Timestamp object at 0x169d4fed0>    1
# <built-in method time of Timestamp object at 0x151ca48b8>    1
# <built-in method time of Timestamp object at 0x14a0a8c00>    1
# <built-in method time of Timestamp object at 0x14fb2b480>    1
# <built-in method time of Timestamp object at 0x1424fa390>    1
# <built-in method time of Timestamp object at 0x16fcd4a98>    1
# <built-in method time of Timestamp object at 0x16398d480>    1
# <built-in method time of Timestamp object at 0x17b0e5390>    1
# <built-in method time of Timestamp object at 0x1528e0d68>    1
# <built-in method time of Timestamp object at 0x178d932a0>    1
# <built-in method time of Timestamp object at 0x144a227c8>    1
# <built-in method time of Timestamp object at 0x1612021b0>    1
# <built-in method time of Timestamp object at 0x14256af48>    1
# <built-in method time of Timestamp object at 0x1681826d8>    1
# <built-in method time of Timestamp object at 0x1635f1390>    1
# ...
